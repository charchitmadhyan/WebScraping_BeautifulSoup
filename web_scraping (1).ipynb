# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#matplotlib inline
import requests
from bs4 import BeautifulSoup

# %%
url="https://insights.blackcoffer.com/is-telehealth-the-future-of-healthcare-3/"

# %%
headers ={'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36'}
r= requests.get(url,headers=headers)
htmlcontent=r.content
print(r.content)
# Out:
# b'<!doctype html >\r\n<!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->\r\n<!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->\r\n<!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->\r\n<head>\r\n    <meta charset="UTF-8" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <link rel="pingback" href="https://insights.blackcoffer.com/xmlrpc.php" />\r\n    <meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<meta property="og:image" content="https://insights.blackcoffer.com/wp-content/uploads/2022/04/kolpp.jpg" /><link rel="icon" type="image/png" href="https://insights.blackcoffer.com/wp-content/uploads/2019/02/Black-432x466-v02.jpg"><link rel="apple-touch-icon-precomposed" sizes="76x76" href="https://insights.blackcoffer.com/wp-content/uploads/2018/12/Black76.png"/><link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://insights.blackcoffer.com/wp-c
# ...

# %%
soup=BeautifulSoup(htmlcontent,'html.parser')

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html >
#
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://insights.blackcoffer.com/xmlrpc.php" rel="pingback"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# ...

# %%
title=soup.title
print(title)
print(title.string)
# Out:
# <title>Is telehealth the future of healthcare? - Blackcoffer Insights</title>
# Is telehealth the future of healthcare? - Blackcoffer Insights

# %%
paras=soup.find_all('p')
print(paras)
# Out:
# [<p>Covid-19 has paved the way for advancements in Telehealth services, which have currently become a significant component of the healthcare industry to cope with the social distancing and lockdown measures, people adapted to telehealth services to avail doctor expertise.</p>, <p>Telehealth’s global market size is projected to grow to $55.6 billion by 2025 from $25.4 billion in 2020 at a CAGR of 16.9% during the period.  According to the statistics provided by the Medical Council of India, the doctor-patient ratio currently is 1:2000. Such a low doctor-patient ratio results in most of the population without any access to proper healthcare facilities. The budding digital infrastructure covers the gaps created by the lack of quality hospital infrastructure and medical staff, allowing doctors to converse with patients in the far-flung rural areas, through telemedicine.</p>, <p>Telemedicine will be a major contributor to filling the current gaps in the healthcare industry, a some of the
# ...

# %%
anchors=soup.find_all('a')
print(anchors)
# Out:
# [<a href="https://www.facebook.com/blackcoffer.consulting" target="_blank" title="Facebook">
# <i class="td-icon-font td-icon-facebook"></i>
# </a>, <a href="https://www.linkedin.com/company/blackcoffer/" target="_blank" title="Linkedin">
# <i class="td-icon-font td-icon-linkedin"></i>
# </a>, <a href="mailto:hello@blackcoffer.com" target="_blank" title="Mail">
# <i class="td-icon-font td-icon-mail-1"></i>
# </a>, <a href="https://join.skype.com/invite/Ersi8ZhOVSSZ" target="_blank" title="Skype">
# <i class="td-icon-font td-icon-skype"></i>
# </a>, <a href="https://twitter.com/Blackcoffer1" target="_blank" title="Twitter">
# <i class="td-icon-font td-icon-twitter"></i>
# ...

# %%
print(soup.find('p'))
# Out:
# <p>Covid-19 has paved the way for advancements in Telehealth services, which have currently become a significant component of the healthcare industry to cope with the social distancing and lockdown measures, people adapted to telehealth services to avail doctor expertise.</p>

# %%
print(soup.get_text())
# Out:
#
#
#
#
#
#
#
#
# Is telehealth the future of healthcare? - Blackcoffer Insights
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Our Success Stories
#
# Banking, Financials, Securities, and Insurance
# Energy
# Entertainment
# Fast Moving Consumer Goods
# Government & Think Tanks
# Healthcare
# Infrastructure & Real Estate
# IT
# Lifestyle, eCommerce & Online Market Place
# Production & Manufacturing
# Research & Academia
# Retail & Supply Chain
# Telecom
#
#
# What We Do
#
# Banking, Financials, Securities, and Insurance
# Energy
# Entertainment
# Fast Moving Consumer Goods
# Government & Think Tanks
# Healthcare
# Hospitality
# Infrastructure & Real Estate
# IT Services
# Lifestyle, eCommerce & Online Market Place
# News & Media
# Production & Manufacturing
# Research & Academia
# Retail & Supply Chain
#
#
# ...

# %%
for word in soup.find_all('p'):
  
    # Obtain the text from the received
    # tags
    text=word.get_text()
  
    # Print the text obtained received 
    # in previous step
    print(text)
# Out:
# Covid-19 has paved the way for advancements in Telehealth services, which have currently become a significant component of the healthcare industry to cope with the social distancing and lockdown measures, people adapted to telehealth services to avail doctor expertise.
# Telehealth’s global market size is projected to grow to $55.6 billion by 2025 from $25.4 billion in 2020 at a CAGR of 16.9% during the period.  According to the statistics provided by the Medical Council of India, the doctor-patient ratio currently is 1:2000. Such a low doctor-patient ratio results in most of the population without any access to proper healthcare facilities. The budding digital infrastructure covers the gaps created by the lack of quality hospital infrastructure and medical staff, allowing doctors to converse with patients in the far-flung rural areas, through telemedicine.
# ...

# %%
title
text = [word.text for word in soup.find_all('p')]

# %%
text
# Out:
# ['Covid-19 has paved the way for advancements in Telehealth services, which have currently become a significant component of the healthcare industry to cope with the social distancing and lockdown measures, people adapted to telehealth services to avail doctor expertise.',
#  'Telehealth’s global market size is projected to grow to $55.6 billion by 2025 from $25.4 billion in 2020 at a CAGR of 16.9% during the period. \xa0According to the statistics provided by the Medical Council of India, the doctor-patient ratio currently is 1:2000. Such a low doctor-patient ratio results in most of the population without any access to proper healthcare facilities. The budding digital infrastructure covers the gaps created by the lack of quality hospital infrastructure and medical staff, allowing doctors to converse with patients in the far-flung rural areas, through telemedicine.',
# ...

# %%
title=title.getText()

# %%
title
# Out:
# 'Is telehealth the future of healthcare? - Blackcoffer Insights'

# %%
data1=[title,text]

# %%
data1
# Out:
# ['Is telehealth the future of healthcare? - Blackcoffer Insights',
#  ['Covid-19 has paved the way for advancements in Telehealth services, which have currently become a significant component of the healthcare industry to cope with the social distancing and lockdown measures, people adapted to telehealth services to avail doctor expertise.',
#   'Telehealth’s global market size is projected to grow to $55.6 billion by 2025 from $25.4 billion in 2020 at a CAGR of 16.9% during the period. \xa0According to the statistics provided by the Medical Council of India, the doctor-patient ratio currently is 1:2000. Such a low doctor-patient ratio results in most of the population without any access to proper healthcare facilities. The budding digital infrastructure covers the gaps created by the lack of quality hospital infrastructure and medical staff, allowing doctors to converse with patients in the far-flung rural areas, through telemedicine.',
# ...

# %%
    with  open(r"C:\Users\Debu bhaiya\Desktop\URL_1.txt", "w") as file:
        file.write(str(data1))
        file.close()
